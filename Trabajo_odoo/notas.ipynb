# %%
import xmlrpc.client

# Datos de conexión
url = "https://sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"
db = "sinergia-lab-tmluc-plataformapasantia-17701702"
username = "cristobal.reyes.l@mail.pucv.cl"
password = "criscris789"

# Autenticación
try:
    common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
    uid = common.authenticate(db, username, password, {})
    
    if uid:
        print(f"Autenticado como {username} (UID: {uid})")
    else:
        raise Exception("Error al autenticar. Verifica tus credenciales.")
except Exception as e:
    print(f"Error de conexión: {e}")

# Conexión a los modelos
try:
    models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")

    # Ejemplo: Consultar los primeros 10 clientes (res.partner)
    partners = models.execute_kw(
        db,
        uid,
        password,
        "res.partner",  # Modelo a consultar
        "search_read",  # Método para buscar y leer
        [
            [],  # Dominio vacío para traer todos los registros
        ],
        {
            "fields": ["name", "email", "phone"],  # Campos a extraer
            "limit": 10,  # Limitar el número de resultados
        },
    )

    # Mostrar resultados
    print("Clientes encontrados:")
    for partner in partners:
        print(f"Nombre: {partner['name']}, Email: {partner.get('email')}, Teléfono: {partner.get('phone')}")
except Exception as e:
    print(f"Error al consultar datos: {e}")
# Out:
# Autenticado como cristobal.reyes.l@mail.pucv.cl (UID: 30)
# Clientes encontrados:
# Nombre: Manuel Aldunate, Email: maldunate@tmluc.com, Teléfono: False
# Nombre: Sinergia Consultores SpA, Email: info@sinergiaindustrias.cl, Teléfono: False
# Nombre: Alejandro Urbina, Email: alejandro.urbina@sinergiaindustrias.cl, Teléfono: False
# Nombre: Bastian Olivares, Email: bastian.olivares@sinergiaindustrias.cl, Teléfono: False
# Nombre: Cristobal Reyes, Email: cristobal.reyes.l@mail.pucv.cl, Teléfono: False
# Nombre: Gonzalo Arancibia, Email: gonzalo.arancibia@sinergiaindustrias.cl, Teléfono: False
# Nombre: Javier Rozas, Email: j.rozas@sinergiaindustrias.cl, Teléfono: False
# Nombre: Ricardo Olivares, Email: ricardo.olivares@sinergiaindustrias.cl, Teléfono: False
# Nombre: TRESMONTES LUCCHETTI S.A., Email: False, Teléfono:
# Nombre: Erick Paredes, Email: eparedes@tmluc.com, Teléfono: False

# %%
import odoolib

# Conexión al cliente de Odoo
try:
    # Crear conexión al servidor
    odoo = odoolib.get_connection(hostname= 'sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com',
                                database= 'sinergia-lab-tmluc-plataformapasantia-17701702',
                                login=    'cristobal.reyes.l@mail.pucv.cl',
                                password= 'criscris789',
                                port=     443,
                                protocol= 'jsonrpcs')
    print("Conexión exitosa a Odoo")
except Exception as e:
    print(f"Error al conectar a Odoo: {e}")
    exit()

# Consulta para obtener IDs de todos los productos
try:
    # Obtener el objeto del modelo de productos
    product_model = odoo.get_model("x_productos")
    
    # Realizar la búsqueda de IDs
    product_ids = product_model.search([])
    print(f"IDs de productos encontrados: {product_ids}")
except Exception as e:
    print(f"Error al realizar la consulta: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import odoolib
#       3 # Conexión al cliente de Odoo
#       4 try:
#       5     # Crear conexión al servidor
#
# ModuleNotFoundError: No module named 'odoolib'

# %%
import odoolib

# Datos de conexión
url = "sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"  # Sin el prefijo https://
db = "sinergia-lab-tmluc-plataformapasantia-17701702"
username = "cristobal.reyes.l@mail.pucv.cl"
password = "criscris789"

# Conexión al cliente de Odoo
try:
    # Crear conexión al servidor
    connection = odoolib.get_connection(
        hostname=url,
        database=db,
        login=username,
        password=password,
        port=443,  # Usar el puerto 443 para HTTPS
        protocol="jsonrpc+ssl"  # Usar protocolo seguro
    )
    print("Conexión exitosa a Odoo")
except Exception as e:
    print(f"Error al conectar a Odoo: {e}")
    exit()

# Consulta para obtener IDs de todos los productos
try:
    # Obtener el objeto del modelo de productos
    product_model = connection.get_model("product.template")
    
    # Realizar la búsqueda de IDs
    product_ids = product_model.search([])
    print(f"IDs de productos encontrados: {product_ids}")
except Exception as e:
    print(f"Error al realizar la consulta: {e}")
# Out:
# Error al conectar a Odoo: You must choose xmlrpc, xmlrpcs, jsonrpc or jsonrpcs
# Error al realizar la consulta: name 'connection' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import xmlrpc.client

# Datos de conexión
url = "https://sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"
db = "sinergia-lab-tmluc-plataformapasantia-17701702"
username = "cristobal.reyes.l@mail.pucv.cl"
password = "criscris789"

# Autenticación
try:
    common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
    uid = common.authenticate(db, username, password, {})
    if not uid:
        raise Exception("Error al autenticar. Verifica tus credenciales.")
    print(f"Autenticado como {username} (UID: {uid})")
except Exception as e:
    print(f"Error de conexión: {e}")

# Conexión a los modelos y consulta de IDs de productos
try:
    models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")
    
    # Consultar IDs de todos los productos
    product_ids = models.execute_kw(
        db,
        uid,
        password,
        "x_productos",  # Modelo de productos
        "search",            # Método para buscar
        [
            []               # Dominio vacío para traer todos los registros
        ]
    )
    
    print(f"IDs de productos encontrados: {product_ids}")
except Exception as e:
    print(f"Error al realizar la consulta: {e}")
# Out:
# Autenticado como cristobal.reyes.l@mail.pucv.cl (UID: 30)
# ...

# %%
import xmlrpc.client

# Datos de conexión
url = "https://sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"
db = "sinergia-lab-tmluc-plataformapasantia-17701702"
username = "cristobal.reyes.l@mail.pucv.cl"
password = "criscris789"

try:
    # Autenticación
    common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
    uid = common.authenticate(db, username, password, {})
    if not uid:
        raise Exception("Error al autenticar. Verifica tus credenciales.")
    print(f"Autenticado como {username} (UID: {uid})")
    
    # Crear conexión al modelo
    models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")
    
    # Buscar el ID del periodo 2024
    period_ids = models.execute_kw(
        db,
        uid,
        password,
        "x_periodo",  # Modelo de periodos
        "search",  # Método de búsqueda
        [[("x_name", "=", "2024")]]  # Suponiendo que el campo 'x_name' contiene el año del periodo
    )

    if not period_ids:
        raise Exception("No se encontró el periodo 2024.")

    period_id = period_ids[0]  # Tomar el primer ID encontrado

    # Buscar productos asociados al periodo 2024
    product_ids = models.execute_kw(
        db,
        uid,
        password,
        "x_productos",  # Modelo de productos
        "search",  # Método de búsqueda
        [[("x_studio_periodos", "=", period_id)]]
    )

    # Contar la cantidad de productos encontrados
    product_count = len(product_ids)

    # Mostrar resultados
    print(f"Cantidad de productos encontrados: {product_count}")
    print(f"IDs de productos asociados al periodo 2024: {product_ids}")

except Exception as e:
    print(f"Error al realizar la consulta: {e}")
# Out:
# Autenticado como cristobal.reyes.l@mail.pucv.cl (UID: 30)
# Cantidad de productos encontrados: 629
# ...

# %%
import xmlrpc.client

# Datos de conexión
url = "https://sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"
db = "sinergia-lab-tmluc-plataformapasantia-17701702"
username = "cristobal.reyes.l@mail.pucv.cl"
password = "criscris789"

try:
    # Autenticación
    common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
    uid = common.authenticate(db, username, password, {})
    if not uid:
        raise Exception("Error al autenticar. Verifica tus credenciales.")
    print(f"Autenticado como {username} (UID: {uid})")
    
    # Crear conexión al modelo
    models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")
    
    # Buscar el ID del periodo 2024
    period_ids = models.execute_kw(
        db,
        uid,
        password,
        "x_periodo",  # Modelo de periodos
        "search",  # Método de búsqueda
        [[("x_name", "=", "2024")]]  # Suponiendo que el campo 'x_name' contiene el año del periodo
    )

    if not period_ids:
        raise Exception("No se encontró el periodo 2024.")

    period_id = period_ids[0]  # Tomar el primer ID encontrado

    # Buscar productos asociados al periodo 2024
    product_ids = models.execute_kw(
        db,
        uid,
        password,
        "x_productos",  # Modelo de productos
        "search",  # Método de búsqueda
        [[("x_studio_periodos", "=", period_id)]]
    )

    # Obtener las descripciones de los productos
    if product_ids:
        products = models.execute_kw(
            db,
            uid,
            password,
            "x_productos",  # Modelo de productos
            "read",  # Método para leer campos específicos
            [product_ids],  # Lista de IDs de productos
            {"fields": ["x_studio_descripcion"]}  # Campo(s) a obtener
        )

        # Mostrar resultados
        print(f"Cantidad de productos encontrados: {len(product_ids)}")
        print("Descripciones de los productos asociados al periodo 2024:")
        for product in products:
            print(f"- ID: {product['id']}, Descripción: {product.get('x_studio_descripcion', 'Sin descripción')}")
    else:
        print("No se encontraron productos asociados al periodo 2024.")

except Exception as e:
    print(f"Error al realizar la consulta: {e}")
# Out:
# Autenticado como cristobal.reyes.l@mail.pucv.cl (UID: 30)
# Cantidad de productos encontrados: 629
# Descripciones de los productos asociados al periodo 2024:
# - ID: 138730, Descripción: LUCCHETTI TALLARIN 78 400 G
# - ID: 138731, Descripción: LUCCHETTI SPAGHETTI  5  400 G
# - ID: 138732, Descripción: LUCCHETTI SPAGHETTI  5 TR3S  400 G
# - ID: 138733, Descripción: LUCCHETTI CABELLO ANGEL 1  400 G
# - ID: 138734, Descripción: TALLIANI SPAGHETTI 5 400G
# - ID: 138735, Descripción: TALLIANI TALLARIN 77 400G
# - ID: 138736, Descripción: TALLIANI TALLARIN 78 400G
# - ID: 138738, Descripción: PASTA FIDOS 3 KG
# - ID: 138739, Descripción: ROMANO TALLARIN 77  400 G
# - ID: 138740, Descripción: SEMOLINA 250 G LUCCHETTI
# - ID: 138741, Descripción: LUCCHETTI  TALLARIN 77  400 G
# - ID: 138742, Descripción: SEMOLA 250 G LUCCHETTI
# - ID: 138743, Descripción: ROMANO SPAGHETTI 5  400 G
# - ID: 138745, Descripción: ACETO BALSAMICO 12X1/2 LT
# ...

# %%
import xmlrpc.client

# Datos de conexión
url = "https://sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"
db = "sinergia-lab-tmluc-plataformapasantia-17701702"
username = "cristobal.reyes.l@mail.pucv.cl"
password = "criscris789"

try:
    # Autenticación
    common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
    uid = common.authenticate(db, username, password, {})
    if not uid:
        raise Exception("Error al autenticar. Verifica tus credenciales.")
    print(f"Autenticado como {username} (UID: {uid})")
    
    # Crear conexión al modelo
    models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")
    
    # Buscar el ID del periodo 2024
    period_ids = models.execute_kw(
        db,
        uid,
        password,
        "x_periodo",  # Modelo de periodos
        "search",  # Método de búsqueda
        [[("x_name", "=", "2024")]]  # Suponiendo que el campo 'x_name' contiene el año del periodo
    )

    if not period_ids:
        raise Exception("No se encontró el periodo 2024.")

    period_id = period_ids[0]  # Tomar el primer ID encontrado

    # Buscar productos asociados al periodo 2024
    product_ids = models.execute_kw(
        db,
        uid,
        password,
        "x_productos",  # Modelo de productos
        "search",  # Método de búsqueda
        [[("x_studio_periodos", "=", period_id)]]
    )

    # Obtener las descripciones y SKUs de los productos
    if product_ids:
        products = models.execute_kw(
            db,
            uid,
            password,
            "x_productos",  # Modelo de productos
            "read",  # Método para leer campos específicos
            [product_ids],  # Lista de IDs de productos
            {"fields": ["x_studio_descripcion", "x_name"]}  # Campos a obtener
        )

        # Mostrar resultados
        print(f"Cantidad de productos encontrados: {len(product_ids)}")
        print("Detalles de los productos asociados al periodo 2024:")
        for product in products:
            print(f"- ID: {product['id']}, SKU: {product.get('x_name', 'Sin SKU')}, Descripción: {product.get('x_studio_descripcion', 'Sin descripción')}")
    else:
        print("No se encontraron productos asociados al periodo 2024.")

except Exception as e:
    print(f"Error al realizar la consulta: {e}")
# Out:
# Autenticado como cristobal.reyes.l@mail.pucv.cl (UID: 30)
# Cantidad de productos encontrados: 629
# Detalles de los productos asociados al periodo 2024:
# - ID: 138730, SKU: 129, Descripción: LUCCHETTI TALLARIN 78 400 G
# - ID: 138731, SKU: 230, Descripción: LUCCHETTI SPAGHETTI  5  400 G
# - ID: 138732, SKU: 235, Descripción: LUCCHETTI SPAGHETTI  5 TR3S  400 G
# - ID: 138733, SKU: 240, Descripción: LUCCHETTI CABELLO ANGEL 1  400 G
# - ID: 138734, SKU: 331, Descripción: TALLIANI SPAGHETTI 5 400G
# - ID: 138735, SKU: 332, Descripción: TALLIANI TALLARIN 77 400G
# - ID: 138736, SKU: 333, Descripción: TALLIANI TALLARIN 78 400G
# - ID: 138738, SKU: 409, Descripción: PASTA FIDOS 3 KG
# - ID: 138739, SKU: 412, Descripción: ROMANO TALLARIN 77  400 G
# - ID: 138740, SKU: 530, Descripción: SEMOLINA 250 G LUCCHETTI
# - ID: 138741, SKU: 533, Descripción: LUCCHETTI  TALLARIN 77  400 G
# - ID: 138742, SKU: 541, Descripción: SEMOLA 250 G LUCCHETTI
# ...

# %%
import xmlrpc.client

# Datos de conexión
url = "https://sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"
db = "sinergia-lab-tmluc-plataformapasantia-17701702"
username = "cristobal.reyes.l@mail.pucv.cl"
password = "criscris789"

try:
    # Autenticación
    common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
    uid = common.authenticate(db, username, password, {})
    if not uid:
        raise Exception("Error al autenticar. Verifica tus credenciales.")
    print(f"Autenticado como {username} (UID: {uid})")
    
    # Crear conexión al modelo
    models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")
    
    # Buscar el ID del periodo 2025
    period_ids = models.execute_kw(
        db,
        uid,
        password,
        "x_periodo",  # Modelo de periodos
        "search",  # Método de búsqueda
        [[("x_name", "=", "2025")]]  # Suponiendo que el campo 'x_name' contiene el año del periodo
    )

    if not period_ids:
        raise Exception("No se encontró el periodo 2025.")

    period_id = period_ids[0]  # Tomar el primer ID encontrado

    # Datos de los nuevos productos
    new_products = [
        {"x_name": "PROD-003", "x_studio_descripcion": "Nuevo producto C", "x_studio_periodos": [(4, period_id)]},
        {"x_name": "PROD-004", "x_studio_descripcion": "Nuevo producto D", "x_studio_periodos": [(4, period_id)]},
    ]

    # Crear nuevos productos
    created_ids = []
    for product_data in new_products:
        product_id = models.execute_kw(
            db,
            uid,
            password,
            "x_productos",  # Modelo de productos
            "create",  # Método para crear registros
            [product_data]
        )
        created_ids.append(product_id)

    print(f"Productos creados con éxito: {created_ids}")

except Exception as e:
    print(f"Error al realizar la operación: {e}")

# %%
from odoo_client import Client

# Datos de conexión
url = "https://sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"
db = "sinergia-lab-tmluc-plataformapasantia-17701702"
username = "cristobal.reyes.l@mail.pucv.cl"
password = "criscris789"

# Conexión al cliente Odoo
client = Client(url, db, username, password)

# Autenticación
try:
    # Obtener UID del usuario
    uid = client.login()
    if not uid:
        raise Exception("Error al autenticar. Verifica tus credenciales.")
    print(f"Autenticado como {username} (UID: {uid})")
except Exception as e:
    print(f"Error de conexión: {e}")

# Conexión a los modelos y consulta de IDs de productos
try:
    # Consultar IDs de todos los productos
    product_ids = client.execute(
        'x_productos',  # Modelo de productos
        'search',       # Método para buscar
        [],             # Dominio vacío para traer todos los registros
    )
    
    print(f"IDs de productos encontrados: {product_ids}")
except Exception as e:
    print(f"Error al realizar la consulta: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from odoo_client import Client
#       3 # Datos de conexión
#       4 url = "https://sinergia-lab-tmluc-plataformapasantia-17701702.dev.odoo.com"
#
# ModuleNotFoundError: No module named 'odoo_client'
